# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate Data
X = np.array([[-0.21, 1.49], [0.65, -2.55], [0.33, 0.44], [1.45, 0.14], [0.4, 1.76], [0.38, 0.15], [0.12, 0.76], 
    [-1.45, 2.27], [-1.98, -0.89], [-0.19, 0.05], [-0.85, 0.31], [-0.74, 0.86], [-0.3, -0.39], [2.24, 0.98], 
    [0.41, -0.1], [0.16, -0.35], [1.47, 1.53], [1.2, 1.23], [-0.15, 0.95], [-0.98, 1.87]])

y = np.array([30.71, -61.86, 24.01, 65.21, 53.13, 21.67, 12.29, 18.42, -106.39, -1.08, -17.32, -11.53, -26.81, 
    131.88, -0.85, -8.91, 102.46, 75.81, 20.08, 18.27])

# Show Data
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)
plt.show()

# %%
# get optimal W using stochastic gradient descent
l = 0.01
iter = 10000
w0 = np.random.randint(-100, 100)
w1 = np.random.randint(-100, 100)
for i in range(iter):
    j = np.random.randint(0, 20)
    w0 = w0 + l * (y[j] - (w0 + w1 * X[j,0]))
    w1 = w1 + l * (y[j] - (w0 + w1 * X[j,1])) * X[j,1]

W = np.array([w0, w1])
print("W = ", W)

# plot the plane
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)
x0 = np.linspace(-3, 3, 100)
x1 = np.linspace(-3, 3, 100)
x0, x1 = np.meshgrid(x0, x1)
ax.plot_surface(x0, x1, W[0]*x0 + W[1]*x1, alpha=0.2)
plt.show()
# Out:
# W =  [18.70024599 24.86458793]

# %%
# Get a new input 
x = np.array([1, 1])

# Predict the output
y = W @ x

# Show result
print("y = ", y)

# Plot the result 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)
x0 = np.linspace(-3, 3, 100)
x1 = np.linspace(-3, 3, 100)
x0, x1 = np.meshgrid(x0, x1)
ax.plot_surface(x0, x1, W[0]*x0 + W[1]*x1, alpha=0.2)
ax.scatter(x[0], x[1], y, color='red')
plt.show()
# Out:
# y =  43.564833918485085
